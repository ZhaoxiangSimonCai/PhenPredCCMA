# %% [markdown]
# # CBA 2026 SHAP Analysis — Target-Level Attribution × Performance (publication-quality rebuild)
#
# Selected +CNV MOSA run: `20260511_174623`.
#
# This notebook is a publication-quality rebuild of the original `cba2026/02_target_level_shap_performance.ipynb`. Selected TabPFN performance (`expanded` × `mosa_all`) is joined to a per-target SHAP composition profile and used as input for downstream diagnostic figures. All plotting flows through `_shap_analysis.py` so the visual style stays consistent with notebook 01.
#
# **Coverage**
# - **Fig 4 — Performance vs SHAP profile** (replaces original Fig 5): four-panel diagnostic using `gridspec` with proper sample-size legend and family-stratified dominant-omic boxplot.
# - **Fig 5 — Selected CRISPR target top features** (replaces original Fig 6): MDM2 / MDM4 / top-Δr backfill panels with consistent styling and per-panel ×10⁻³ axis. Targets unavailable in the SHAP export are noted explicitly.
# - **Fig 6 — Selected CRISPR target omic composition** (replaces original Fig 7): magma heatmap with annotated cell values and luminance-aware text colour.
# - **Fig 7 — CNV gain volcano** (new): ΔPearson r vs CNV share of top-200 SHAP, with leader-line callouts for the top-10 gainers per family.
# - Tables: per-target summary, top gain / loss vs RF baseline, high-CNV-share targets.

# %%
import sys
from pathlib import Path

import pandas as pd
from IPython.display import Image, display

sys.path.insert(0, str(Path.cwd()))
import _shap_analysis as shap_an

print(f"ROOT     = {shap_an.ROOT}")
print(f"FIG_DIR  = {shap_an.FIG_DIR}")
# Out:
# ROOT     = /mnt/scratch/scai/PhenPredCCMA
# FIG_DIR  = /mnt/scratch/scai/PhenPredCCMA/reports/cba2026_claude_union/shap_analysis/20260511_174623

# %% [markdown]
# ## Build the analysis frame
#
# `load_shap_tables()` and `load_performance()` read all required inputs. `assemble_analysis_table` produces one row per (family, target) with: top200-share per omic layer, dominant-omic flag, omic-entropy, copy-number feature count, selected TabPFN test-set Pearson r and the Δr versus the random-forest `overlap × original` baseline.

# %%
tables = shap_an.load_shap_tables()
performance = shap_an.load_performance()
analysis = shap_an.assemble_analysis_table(tables, performance)

missing_perf = analysis["test_pearsonr_tabpfn"].isna().sum()
if missing_perf:
    print(f"Warning: {missing_perf} SHAP targets did not match per-target performance rows.")

analysis.groupby("target_label")[[
    "test_pearsonr_tabpfn",
    "delta_pearsonr_vs_rf",
    "share_copynumber",
    "omic_entropy",
]].describe().round(3)
# Out:
#               test_pearsonr_tabpfn                                            \
#                              count   mean    std    min    25%    50%    75%
# target_label
# CRISPR-Cas9                  500.0  0.220  0.250 -0.695  0.055  0.226  0.399
# Drug response                500.0  0.348  0.244 -0.296  0.176  0.353  0.528
#
#                      delta_pearsonr_vs_rf         ... share_copynumber         \
#                  max                count   mean  ...              75%    max
# target_label                                      ...
# CRISPR-Cas9    0.863                500.0  0.069  ...              0.0  0.248
# Drug response  0.897                500.0  0.113  ...              0.0  0.163
#
#               omic_entropy
#                      count   mean    std    min    25%    50%    75%    max
# target_label
# CRISPR-Cas9          500.0  0.326  0.147  0.050  0.214  0.305  0.424  0.874
# Drug response        500.0  0.514  0.099  0.111  0.462  0.533  0.583  0.741
#
# [2 rows x 32 columns]

# %% [markdown]
# ## Figure 4 — Performance vs SHAP profile (4-panel diagnostic)
#
# - **(a)** Per-family Pearson r distribution (step histogram, density-normalised).
# - **(b)** Copy-number share of top-200 SHAP vs Pearson r — does CNV attribution track better-predicted targets?
# - **(c)** Omic entropy of top-200 SHAP vs Δr versus RF — do well-distributed attributions correspond to the +CNV-MOSA gain?
# - **(d)** Pearson r grouped by the dominant omic layer of each target's top-200 SHAP, family-stratified boxplots.
#
# All scatter panels are rasterised so the saved PDF stays small (text remains vector and editable).

# %%
fig4_pdf = shap_an.fig4_performance_vs_profile(analysis)
display(Image(filename=str(fig4_pdf.with_suffix(".png")), embed=True))

# %% [markdown]
# ## Figure 5 — Selected CRISPR target top features
#
# Bar plots of the top-18 SHAP features per requested CRISPR target. TP53 is requested but **not** present in the top-features SHAP export; the function backfills any unavailable slot with the highest-Δr CRISPR target so the panel layout stays balanced and biologically interpretable. Each panel uses an independent x-axis (per-target SHAP scales differ by ≈10×); the panel title carries Pearson r and Δr.

# %%
fig5_pdf, plotted_targets, missing_targets = shap_an.fig5_selected_crispr_top_features(
    tables, analysis, requested=("TP53", "MDM2", "MDM4"), top_n=18,
)
if missing_targets:
    print(f"Requested targets unavailable in SHAP export: {missing_targets}")
print(f"Targets actually plotted: {plotted_targets}")
display(Image(filename=str(fig5_pdf.with_suffix(".png")), embed=True))
# Out:
# Requested targets unavailable in SHAP export: ['TP53']
# Targets actually plotted: ['MDM2', 'MDM4', 'TAF1B']

# %% [markdown]
# ## Figure 6 — Selected CRISPR target omic composition
#
# Heatmap of top-200 SHAP share by omic layer for the same selected targets, with annotated cell values. Magma colormap is luminance-aware, so the cell-value text colour is chosen automatically to stay legible against the background.

# %%
fig6_pdf = shap_an.fig6_selected_crispr_omic_heatmap(analysis, targets=plotted_targets)
display(Image(filename=str(fig6_pdf.with_suffix(".png")), embed=True))

# %% [markdown]
# ## Figure 7 — CNV gain volcano (new)
#
# ΔPearson r versus copy-number share of top-200 SHAP, per family. The top-10 Δr targets per family are outlined in brick red and labelled in a callout column on the right of each panel; leader lines connect markers to labels so labels never collide with markers or with each other. This figure highlights the targets where adding CNV both produced a measurable performance lift over the RF baseline and shifted the SHAP profile towards CNV.

# %%
fig7_pdf = shap_an.fig7_cnv_gain_volcano(analysis)
display(Image(filename=str(fig7_pdf.with_suffix(".png")), embed=True))

# %% [markdown]
# ## Follow-up tables
#
# Per-target summary plus winners/losers vs the RF baseline and the most CNV-attributed targets per family.

# %%
table_paths = shap_an.write_tables(tables, analysis)
for name, path in table_paths.items():
    print(f"{name}: {path.relative_to(shap_an.ROOT)}")
# Out:
# table_global_copynumber_feature_ranking: reports/cba2026_claude_union/shap_analysis/20260511_174623/table_global_copynumber_feature_ranking.csv
# table_copynumber_feature_frequency_top200: reports/cba2026_claude_union/shap_analysis/20260511_174623/table_copynumber_feature_frequency_top200.csv
# table_target_copynumber_share_top200: reports/cba2026_claude_union/shap_analysis/20260511_174623/table_target_copynumber_share_top200.csv
# target_level_shap_performance_summary: reports/cba2026_claude_union/shap_analysis/20260511_174623/target_level_shap_performance_summary.csv
# targets_high_copynumber_shap_share: reports/cba2026_claude_union/shap_analysis/20260511_174623/targets_high_copynumber_shap_share.csv
# targets_top_gain_loss_vs_rf_baseline: reports/cba2026_claude_union/shap_analysis/20260511_174623/targets_top_gain_loss_vs_rf_baseline.csv

# %%
gains = pd.read_csv(table_paths["targets_top_gain_loss_vs_rf_baseline"])
gains[[
    "direction", "target_label", "target_name", "test_pearsonr_tabpfn",
    "test_pearsonr_rf_baseline", "delta_pearsonr_vs_rf",
    "dominant_omic", "share_copynumber",
]].head(20)
# Out:
#    direction target_label target_name  test_pearsonr_tabpfn  \
# 0   top_gain  CRISPR-Cas9       TAF1B              0.621052
# 1   top_gain  CRISPR-Cas9     RANGAP1              0.495099
# 2   top_gain  CRISPR-Cas9       HAUS2              0.178738
# 3   top_gain  CRISPR-Cas9       PSMA2              0.227224
# 4   top_gain  CRISPR-Cas9       BARD1              0.392273
# 5   top_gain  CRISPR-Cas9      POLR3A              0.323901
# 6   top_gain  CRISPR-Cas9      POLR3B              0.556412
# 7   top_gain  CRISPR-Cas9     SMARCC1              0.708262
# 8   top_gain  CRISPR-Cas9       AURKB              0.226459
# 9   top_gain  CRISPR-Cas9        XPO5              0.465502
# 10  top_gain  CRISPR-Cas9       RBM39              0.440799
# 11  top_gain  CRISPR-Cas9      HMGCS1              0.346931
# 12  top_gain  CRISPR-Cas9      SNRPD1              0.404673
# 13  top_gain  CRISPR-Cas9     TRMT112              0.483362
# 14  top_gain  CRISPR-Cas9       STX18              0.445814
# 15  top_gain  CRISPR-Cas9       WDR12              0.632024
# 16  top_gain  CRISPR-Cas9       RPS26              0.471349
# 17  top_gain  CRISPR-Cas9       VPS25              0.533625
# 18  top_gain  CRISPR-Cas9      RUVBL1              0.643792
# 19  top_gain  CRISPR-Cas9       GINS3              0.306265
#
#     test_pearsonr_rf_baseline  delta_pearsonr_vs_rf    dominant_omic  \
# 0                    0.012672              0.608379  transcriptomics
# 1                   -0.093345              0.588444  transcriptomics
# 2                   -0.406589              0.585326  transcriptomics
# 3                   -0.357518              0.584742  transcriptomics
# 4                   -0.182286              0.574558  transcriptomics
# 5                   -0.235247              0.559147  transcriptomics
# 6                    0.012839              0.543572  transcriptomics
# 7                    0.165370              0.542892  transcriptomics
# 8                   -0.304089              0.530548  transcriptomics
# 9                   -0.025307              0.490809  transcriptomics
# 10                  -0.042943              0.483742  transcriptomics
# 11                  -0.116201              0.463131  transcriptomics
# 12                  -0.046309              0.450982  transcriptomics
# 13                   0.035575              0.447788  transcriptomics
# 14                  -0.001933              0.447747  transcriptomics
# 15                   0.193867              0.438157  transcriptomics
# 16                   0.044782              0.426567  transcriptomics
# 17                   0.107156              0.426469  transcriptomics
# 18                   0.226611              0.417181  transcriptomics
# 19                  -0.106018              0.412283  transcriptomics
#
#     share_copynumber
# 0           0.000000
# 1           0.008263
# 2           0.000000
# 3           0.000000
# 4           0.000000
# 5           0.000000
# 6           0.000000
# 7           0.000000
# 8           0.000000
# 9           0.000000
# 10          0.000000
# 11          0.000000
# 12          0.000000
# 13          0.000000
# 14          0.000000
# 15          0.000000
# 16          0.000000
# 17          0.000000
# 18          0.000000
# 19          0.000000

# %%
cnv_top = pd.read_csv(table_paths["targets_high_copynumber_shap_share"])
cnv_top[[
    "target_label", "target_name", "share_copynumber", "copynumber_n_top200",
    "test_pearsonr_tabpfn", "delta_pearsonr_vs_rf", "dominant_omic",
]].head(20)
# Out:
#    target_label target_name  share_copynumber  copynumber_n_top200  \
# 0   CRISPR-Cas9       EIF3A          0.248216                   38
# 1   CRISPR-Cas9      EIF1AX          0.239911                   38
# 2   CRISPR-Cas9       WDR75          0.235376                   38
# 3   CRISPR-Cas9      PCYT1A          0.234796                   38
# 4   CRISPR-Cas9        UBR4          0.230793                   38
# 5   CRISPR-Cas9       PRORP          0.224021                   38
# 6   CRISPR-Cas9     RACGAP1          0.223463                   38
# 7   CRISPR-Cas9       SETD2          0.220590                   38
# 8   CRISPR-Cas9       INTS8          0.218799                   38
# 9   CRISPR-Cas9       CENPW          0.216617                   38
# 10  CRISPR-Cas9       DDX59          0.213056                   38
# 11  CRISPR-Cas9       AARS1          0.204648                   38
# 12  CRISPR-Cas9       MED12          0.202853                   38
# 13  CRISPR-Cas9       PSMB7          0.198311                   37
# 14  CRISPR-Cas9       RAD51          0.193853                   38
# 15  CRISPR-Cas9        SMC2          0.187946                   37
# 16  CRISPR-Cas9      DCAF13          0.179468                   37
# 17  CRISPR-Cas9        FNTA          0.177786                   36
# 18  CRISPR-Cas9      PRPF39          0.177025                   37
# 19  CRISPR-Cas9      EIF4A3          0.172006                   36
#
#     test_pearsonr_tabpfn  delta_pearsonr_vs_rf    dominant_omic
# 0               0.107871              0.067516  transcriptomics
# 1               0.121662             -0.122286  transcriptomics
# 2              -0.279552             -0.015385  transcriptomics
# 3               0.707385              0.033303  transcriptomics
# 4               0.086007              0.093321  transcriptomics
# 5               0.283656             -0.100874  transcriptomics
# 6               0.169662             -0.174812  transcriptomics
# 7              -0.191639             -0.145599  transcriptomics
# 8               0.380312              0.239757  transcriptomics
# 9              -0.002792             -0.136157  transcriptomics
# 10              0.162865             -0.172452  transcriptomics
# 11             -0.110883             -0.162403  transcriptomics
# 12              0.426378              0.038900  transcriptomics
# 13              0.113992              0.010288  transcriptomics
# 14              0.636126              0.216624  transcriptomics
# 15              0.158917              0.077305  transcriptomics
# 16              0.168494             -0.078599  transcriptomics
# 17              0.342653              0.104327  transcriptomics
# 18              0.239946              0.181854  transcriptomics
# 19              0.062200              0.109468  transcriptomics

# %% [markdown]
# ## Output files

# %%
for path in sorted(shap_an.FIG_DIR.glob("fig*")):
    print(path.relative_to(shap_an.ROOT))
for path in sorted(shap_an.FIG_DIR.glob("*target*csv")):
    print(path.relative_to(shap_an.ROOT))
# Out:
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig1_global_landscape.pdf
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig1_global_landscape.png
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig2_global_feature_heatmap.pdf
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig2_global_feature_heatmap.png
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig3_target_omic_composition.pdf
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig3_target_omic_composition.png
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig4_performance_vs_profile.pdf
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig4_performance_vs_profile.png
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig5_selected_crispr_top_features.pdf
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig5_selected_crispr_top_features.png
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig6_selected_crispr_omic_composition.pdf
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig6_selected_crispr_omic_composition.png
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig7_cnv_gain_volcano.pdf
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig7_cnv_gain_volcano.png
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig8_shap_concentration.pdf
# reports/cba2026_claude_union/shap_analysis/20260511_174623/fig8_shap_concentration.png
# reports/cba2026_claude_union/shap_analysis/20260511_174623/table_target_copynumber_share_top200.csv
# reports/cba2026_claude_union/shap_analysis/20260511_174623/target_level_shap_performance_summary.csv
# reports/cba2026_claude_union/shap_analysis/20260511_174623/targets_high_copynumber_shap_share.csv
# reports/cba2026_claude_union/shap_analysis/20260511_174623/targets_top_gain_loss_vs_rf_baseline.csv
