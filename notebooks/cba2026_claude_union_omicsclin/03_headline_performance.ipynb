# %% [markdown]
# # CBA 2026 — Notebook 03: Headline performance
#
# Aggregate prediction story for the CBA 2026 talk. Builds Figs P1–P4:
#
# | Fig | What it shows |
# | --- | --- |
# | P1 | Headline grid: mean per-target Pearson r, R², pooled Pearson r, train_n by 3 variants × 2 frames × {TabPFN, RF}, faceted by family. |
# | P2 | Per-target paired RF↔TabPFN scatter (CRISPR / drug). |
# | P3 | ΔPearson r decomposition: distribution, cumulative win-rate, MOSA-only and model-only contributions. |
# | P4 | Variant × frame heatmap of mean Pearson r and the matching train_n cohort-expansion bar. |
#
# Outputs land at `reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/` (composites) and `…/singles/` (single-panel slide cuts). All figure code lives in `_prediction_analysis.py`; this notebook is just the driver.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))

import _prediction_analysis as pred
from IPython.display import Image, display

print(f"ROOT     = {pred.ROOT}")
print(f"FIG_DIR  = {pred.FIG_DIR.relative_to(pred.ROOT)}")
print(f"SINGLE   = {pred.SINGLE_FIG_DIR.relative_to(pred.ROOT)}")
# Out:
# ROOT     = /mnt/scratch/scai/PhenPredCCMA
# FIG_DIR  = reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623
# SINGLE   = reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles

# %% [markdown]
# ## Load comparison frames
#
# Three master tables drive every panel: a long-form summary (24 rows), a long-form per-target frame (~12k rows), and a per-target wide "decomposed" frame with the four headline levers.

# %%
summary_long = pred.load_summary_long()
per_target_long = pred.load_per_target_long()
decomposed = pred.load_decomposed()

print(f"summary_long    : {summary_long.shape}")
print(f"per_target_long : {per_target_long.shape}")
print(f"decomposed      : {decomposed.shape}")
summary_long.head(8)
# Out:
# summary_long    : (24, 20)
# per_target_long : (12000, 11)
# decomposed      : (1000, 37)
#         experiment_name target_family sample_frame        variant  \
# 0  feature_augmentation    crisprcas9      overlap       original
# 1  feature_augmentation    crisprcas9      overlap  mosa_nan_only
# 2  feature_augmentation    crisprcas9      overlap       mosa_all
# 3  feature_augmentation    crisprcas9     expanded       original
# 4  feature_augmentation    crisprcas9     expanded  mosa_nan_only
# 5  feature_augmentation    crisprcas9     expanded       mosa_all
# 6  feature_augmentation    crisprcas9      overlap       original
# 7  feature_augmentation    crisprcas9      overlap  mosa_nan_only
#
#     mosa_timestamp tabpfn_estimator_mode  \
# 0  20260511_174623              standard
# 1  20260511_174623              standard
# 2  20260511_174623              standard
# 3  20260511_174623              standard
# 4  20260511_174623              standard
# 5  20260511_174623              standard
# 6  20260511_174623                   NaN
# 7  20260511_174623                   NaN
#
#                         tabpfn_model_label  tabpfn_model_count  train_n  \
# 0  tabpfn-v2.5-regressor-v2.5_default.ckpt                 1.0       95
# 1  tabpfn-v2.5-regressor-v2.5_default.ckpt                 1.0       95
# 2  tabpfn-v2.5-regressor-v2.5_default.ckpt                 1.0       95
# 3  tabpfn-v2.5-regressor-v2.5_default.ckpt                 1.0      140
# 4  tabpfn-v2.5-regressor-v2.5_default.ckpt                 1.0      140
# 5  tabpfn-v2.5-regressor-v2.5_default.ckpt                 1.0      140
# 6                                      NaN                 NaN       95
# 7                                      NaN                 NaN       95
#
#    test_n  target_count  selected_feature_count   test_r2  test_pearsonr  \
# 0      24           500                    2000 -0.039459       0.137967
# 1      24           500                    2000 -0.039425       0.141473
# 2      24           500                    2000 -0.025222       0.182965
# 3      24           500                    2000 -0.065381       0.154562
# 4      24           500                    2000 -0.064934       0.155550
# 5      24           500                    2000 -0.000916       0.212581
# 6      24           500                    2000 -0.042865       0.149940
# 7      24           500                    2000 -0.044724       0.145838
#
#    test_rmse  pooled_test_pearsonr  pooled_test_rmse  test_observation_count  \
# 0   0.660646              0.746350          0.673573                   11932
# 1   0.660615              0.746401          0.673525                   11932
# 2   0.655870              0.750200          0.669100                   11932
# 3   0.666708              0.742052          0.679942                   11932
# 4   0.666282              0.742290          0.679330                   11932
# 5   0.648394              0.756092          0.662171                   11932
# 6   0.661734              0.745418          0.674385                   11932
# 7   0.662470              0.744724          0.675174                   11932
#
#         metric_aggregation     model_name
# 0  macro_mean_over_targets         tabpfn
# 1  macro_mean_over_targets         tabpfn
# 2  macro_mean_over_targets         tabpfn
# 3  macro_mean_over_targets         tabpfn
# 4  macro_mean_over_targets         tabpfn
# 5  macro_mean_over_targets         tabpfn
# 6  macro_mean_over_targets  random_forest
# 7  macro_mean_over_targets  random_forest

# %% [markdown]
# ## Sanity check — abstract numbers reproduce
#
# Mean per-target Pearson r at TabPFN × expanded × MOSA(all) should be ≈ 0.21 (CRISPR) and ≈ 0.32 (drug); RF × overlap × original should be ≈ 0.15 (CRISPR) and ≈ 0.23 (drug).

# %%
import pandas as pd

checks = []
for family in pred.FAMILY_ORDER:
    for label, model, frame, variant in [
        ("abstract headline (TabPFN+MOSA)", "tabpfn",        "expanded", "mosa_all"),
        ("abstract baseline (RF+original)", "random_forest", "overlap",  "original"),
    ]:
        sub = per_target_long[
            (per_target_long["target_family"] == family)
            & (per_target_long["model_name"] == model)
            & (per_target_long["sample_frame"] == frame)
            & (per_target_long["variant"] == variant)
        ]
        m, lo, hi = pred.bootstrap_mean_ci(sub["test_pearsonr"].values)
        checks.append({
            "family": family, "condition": label,
            "mean_r": round(m, 3), "ci_lo": round(lo, 3), "ci_hi": round(hi, 3),
            "n": int((~sub["test_pearsonr"].isna()).sum()),
        })
pd.DataFrame(checks)
# Out:
#          family                        condition  mean_r  ci_lo  ci_hi    n
# 0    crisprcas9  abstract headline (TabPFN+MOSA)   0.213  0.191  0.234  500
# 1    crisprcas9  abstract baseline (RF+original)   0.150  0.129  0.170  500
# 2  drugresponse  abstract headline (TabPFN+MOSA)   0.347  0.325  0.369  500
# 3  drugresponse  abstract baseline (RF+original)   0.229  0.207  0.250  500

# %% [markdown]
# ## Figure P1 — headline performance grid

# %%
p1 = pred.figP1_headline_grid(summary_long, per_target_long)
display(Image(filename=str(p1.with_suffix(".png"))))
print(p1.relative_to(pred.ROOT))
# Out:
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/figP1_headline_performance.pdf

# %% [markdown]
# ## Figure P2 — paired per-target scatter

# %%
p2 = pred.figP2_paired_scatter(decomposed)
display(Image(filename=str(p2.with_suffix(".png"))))
print(p2.relative_to(pred.ROOT))
# Out:
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/figP2_paired_scatter.pdf

# %% [markdown]
# ## Figure P3 — ΔPearson r decomposition
#
# Disentangles the headline gain into a model effect (RF → TabPFN) and a data effect (original → MOSA). Holding sample frame fixed at *expanded* keeps the comparison free of cohort-size confounds.

# %%
p3 = pred.figP3_decomposition(decomposed)
display(Image(filename=str(p3.with_suffix(".png"))))
print(p3.relative_to(pred.ROOT))
# Out:
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/figP3_decomposition.pdf

# %% [markdown]
# ## Figure P4 — strategy & sample frame

# %%
p4 = pred.figP4_strategy_frame(summary_long)
display(Image(filename=str(p4.with_suffix(".png"))))
print(p4.relative_to(pred.ROOT))
# Out:
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/figP4_strategy_frame.pdf

# %% [markdown]
# ## Slide-friendly singles for these four composites
#
# Single-panel exports (column type scale) for direct slide inserts. Bar panels split per family so each takes one slide cleanly.

# %%
singles = [
    pred.single_figP1a_mean_r_crispr(summary_long, per_target_long),
    pred.single_figP1b_mean_r_drug(summary_long, per_target_long),
    pred.single_figP1c_pooled_crispr(summary_long, per_target_long),
    pred.single_figP1d_pooled_drug(summary_long, per_target_long),
    pred.single_figP1e_train_n_crispr(summary_long, per_target_long),
    pred.single_figP1f_train_n_drug(summary_long, per_target_long),
    pred.single_figP2a_paired_crispr(decomposed),
    pred.single_figP2b_paired_drug(decomposed),
    pred.single_figP3a_distribution(decomposed),
    pred.single_figP3b_winrate(decomposed),
    pred.single_figP4a_heatmap_crispr(summary_long),
    pred.single_figP4b_heatmap_drug(summary_long),
]
for p in singles:
    print(p.relative_to(pred.ROOT))
# Out:
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP1a_mean_r_crispr.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP1b_mean_r_drug.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP1c_pooled_crispr.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP1d_pooled_drug.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP1e_train_n_crispr.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP1f_train_n_drug.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP2a_paired_crispr.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP2b_paired_drug.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP3a_distribution.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP3b_winrate.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP4a_heatmap_crispr.pdf
# reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/singles/single_figP4b_heatmap_drug.pdf

# %% [markdown]
# ## Tables
#
# `prediction_summary_by_condition.csv` and `prediction_wilcoxon_summary.csv` are built by `write_prediction_tables`; here we just emit them and preview.

# %%
table_paths = pred.write_prediction_tables(summary_long, per_target_long, decomposed)
for k, v in table_paths.items():
    print(f"{k:45s}  {v.relative_to(pred.ROOT)}")
import pandas as pd
pd.read_csv(table_paths["prediction_wilcoxon_summary"]).round(3)
# Out:
# prediction_summary_by_condition                reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/prediction_summary_by_condition.csv
# prediction_wilcoxon_summary                    reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/prediction_wilcoxon_summary.csv
# prediction_per_target_decomposed               reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/prediction_per_target_decomposed.csv
# prediction_top_gainers                         reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/prediction_top_gainers.csv
# prediction_selected_target_residuals           reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/prediction_selected_target_residuals.csv
# prediction_imputation_scope                    reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/prediction_imputation_scope.csv
# prediction_model_consistency                   reports/cba2026_claude_union_omicsclin/prediction_analysis/20260511_174623/prediction_model_consistency.csv
#   target_family                                 comparison  n_paired  \
# 0    crisprcas9                 TabPFN+MOSA vs RF baseline       500
# 1    crisprcas9          RF MOSA vs RF original (expanded)       500
# 2    crisprcas9  TabPFN MOSA vs TabPFN original (expanded)       500
# 3    crisprcas9                  TabPFN vs RF on MOSA data       500
# 4  drugresponse                 TabPFN+MOSA vs RF baseline       500
# 5  drugresponse          RF MOSA vs RF original (expanded)       500
# 6  drugresponse  TabPFN MOSA vs TabPFN original (expanded)       500
# 7  drugresponse                  TabPFN vs RF on MOSA data       500
#
#    wilcoxon_p  mean_target  mean_ref
# 0       0.000        0.213     0.150
# 1       0.015        0.191     0.178
# 2       0.000        0.213     0.155
# 3       0.000        0.213     0.191
# 4       0.000        0.347     0.229
# 5       0.032        0.281     0.267
# 6       0.000        0.347     0.227
# 7       0.000        0.347     0.281
